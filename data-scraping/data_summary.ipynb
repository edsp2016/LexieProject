# %%
import pandas as pd
import numpy as np

# %%
Location=r'movies_raw_data.xlsx'
df = pd.read_excel(Location)

# %%
Location2=r'imdb_rating.xls'
df2= pd.read_excel(Location2)

# %%
df.head()
# Out:
#    Number  Rank                         Title Studio  Worldwide Domestic   \
# 0       1     1                        Avatar    Fox     2788.0     760.5
# 1       2     2                       Titanic   Par.     2186.8     658.7
# 2       3     3  Star Wars: The Force Awakens     BV     2042.5     923.7
# 3       4     4                Jurassic World   Uni.     1670.4     652.3
# 4       5     5         Marvel's The Avengers     BV     1519.6     623.4
#
#    Dome_perc  Overseas   Over_perc   Year   ...         release_date  \
# 0      0.273     2027.5      0.727  2009^   ...    December 18, 2009
# 1      0.301     1528.1      0.699  1997^   ...    December 19, 1997
# 2      0.452     1118.8      0.548   2015   ...    December 18, 2015
# 3      0.390     1018.1      0.610   2015   ...        June 12, 2015
# 4      0.410      896.2      0.590   2012   ...          May 4, 2012
#
#                 genre          runtime   mpaa        budget opening_weekend  \
# ...

# %%
df2.head()
# Out:
#    Number  Rank                         Title Studio  Worldwide Domestic   \
# 0       1     1                        Avatar    Fox     2788.0     760.5
# 1       2     2                       Titanic   Par.     2186.8     658.7
# 2       3     3  Star Wars: The Force Awakens     BV     2042.5     923.7
# 3       4     4                Jurassic World   Uni.     1670.4     652.3
# 4       5     5         Marvel's The Avengers     BV     1519.6     623.4
#
#    Dome_perc  Overseas   Over_perc   Year  Rating    Imdb_id
# 0      0.273     2027.5      0.727  2009^     7.9  tt0499549
# 1      0.301     1528.1      0.699  1997^     7.7  tt0120338
# 2      0.452     1118.8      0.548   2015     8.4  tt2488496
# 3      0.390     1018.1      0.610   2015     7.1  tt0369610
# 4      0.410      896.2      0.590   2012     8.1  tt0848228

# %% [markdown]
# # Prepare Data

# %%
df['Studio'].unique()
# Out:
# array(['Fox', 'Par.', 'BV', 'Uni.', 'WB', 'P/DW', 'NL', 'Sony', 'WB (NL)',
#        'DW', 'LGF', 'LG/S', 'Sum.', 'NM', 'TriS', 'MGM', 'Wein.', 'Orion',
#        'FR', 'FoxS', 'IFC', 'Mira.', 'Col.', 'UA', 'SGem', 'SonR', 'RKO',
#        'W/Dim.', 'Gram.', 'Art.', nan, 'Rela.', 'Lions', 'Dim.', 'Dis.',
#        'Vest', 'SPC', 'USA'], dtype=object)

# %%
df['rating']=df2['Rating']
df.head()
# Out:
#    Number  Rank                         Title Studio  Worldwide Domestic   \
# 0       1     1                        Avatar    Fox     2788.0     760.5
# 1       2     2                       Titanic   Par.     2186.8     658.7
# 2       3     3  Star Wars: The Force Awakens     BV     2042.5     923.7
# 3       4     4                Jurassic World   Uni.     1670.4     652.3
# 4       5     5         Marvel's The Avengers     BV     1519.6     623.4
#
#    Dome_perc  Overseas   Over_perc   Year  ...                 genre  \
# 0      0.273     2027.5      0.727  2009^  ...      Sci-Fi Adventure
# 1      0.301     1528.1      0.699  1997^  ...               Romance
# 2      0.452     1118.8      0.548   2015  ...        Sci-Fi Fantasy
# 3      0.390     1018.1      0.610   2015  ...         Sci-Fi Horror
# 4      0.410      896.2      0.590   2012  ...    Action / Adventure
#
#            runtime   mpaa        budget opening_weekend             duration  \
# ...

# %%
del df['Dome_perc']
del df['Over_perc']
del df['url']
df.head()
# Out:
#    Number  Rank                         Title Studio  Worldwide Domestic   \
# 0       1     1                        Avatar    Fox     2788.0     760.5
# 1       2     2                       Titanic   Par.     2186.8     658.7
# 2       3     3  Star Wars: The Force Awakens     BV     2042.5     923.7
# 3       4     4                Jurassic World   Uni.     1670.4     652.3
# 4       5     5         Marvel's The Avengers     BV     1519.6     623.4
#
#    Overseas    Year       release_date               genre          runtime  \
# 0     2027.5  2009^  December 18, 2009    Sci-Fi Adventure   2 hrs. 40 min.
# 1     1528.1  1997^  December 19, 1997             Romance   3 hrs. 14 min.
# 2     1118.8   2015  December 18, 2015      Sci-Fi Fantasy   2 hrs. 16 min.
# 3     1018.1   2015      June 12, 2015       Sci-Fi Horror    2 hrs. 4 min.
# 4      896.2   2012        May 4, 2012  Action / Adventure   2 hrs. 22 min.
#
# ...

# %%
#df['opening_weekend'].convert_objects(convert_numeric=True)
df['opening_weekend']=df['opening_weekend'].str.replace(',','')
df['theater']=df['theater'].str.replace(',','')
df['actors']=df['actors'].str.replace(',','')

# %%
df.head()
# Out:
#    Number  Rank                         Title Studio  Worldwide Domestic   \
# 0       1     1                        Avatar    Fox     2788.0     760.5
# 1       2     2                       Titanic   Par.     2186.8     658.7
# 2       3     3  Star Wars: The Force Awakens     BV     2042.5     923.7
# 3       4     4                Jurassic World   Uni.     1670.4     652.3
# 4       5     5         Marvel's The Avengers     BV     1519.6     623.4
#
#    Overseas    Year       release_date               genre          runtime  \
# 0     2027.5  2009^  December 18, 2009    Sci-Fi Adventure   2 hrs. 40 min.
# 1     1528.1  1997^  December 19, 1997             Romance   3 hrs. 14 min.
# 2     1118.8   2015  December 18, 2015      Sci-Fi Fantasy   2 hrs. 16 min.
# 3     1018.1   2015      June 12, 2015       Sci-Fi Horror    2 hrs. 4 min.
# 4      896.2   2012        May 4, 2012  Action / Adventure   2 hrs. 22 min.
#
# ...

# %%
df['opening_weekend']=df['opening_weekend'].str.replace('$','')
df['Title']=df['Title'].str.replace(',','')
df['budget']=df['budget'].str.replace('$','')
df.head()
# Out:
#    Number  Rank                         Title Studio  Worldwide Domestic   \
# 0       1     1                        Avatar    Fox     2788.0     760.5
# 1       2     2                       Titanic   Par.     2186.8     658.7
# 2       3     3  Star Wars: The Force Awakens     BV     2042.5     923.7
# 3       4     4                Jurassic World   Uni.     1670.4     652.3
# 4       5     5         Marvel's The Avengers     BV     1519.6     623.4
#
#    Overseas    Year       release_date               genre          runtime  \
# 0     2027.5  2009^  December 18, 2009    Sci-Fi Adventure   2 hrs. 40 min.
# 1     1528.1  1997^  December 19, 1997             Romance   3 hrs. 14 min.
# 2     1118.8   2015  December 18, 2015      Sci-Fi Fantasy   2 hrs. 16 min.
# 3     1018.1   2015      June 12, 2015       Sci-Fi Horror    2 hrs. 4 min.
# 4      896.2   2012        May 4, 2012  Action / Adventure   2 hrs. 22 min.
#
# ...

# %%
df['budget']=df['budget'].str.replace('million','')

# %%
df.to_csv('undo_data.txt', index=False)
print('Done')
# Out:
# Done

# %% [markdown]
# # Clean data

# %% [markdown]
# Clean data:
# 1. transfer opening_weekend, bugdet,data to millon level
# 2. split genre, actors and director names
# 3. change year, runtime,duration,release_date type

# %% [markdown]
# Missing data:
# 1. Director, actors,...
# Categorical data:
# 1. Studio
# 2. Period
# 3. Genre
# 4. mpaa
